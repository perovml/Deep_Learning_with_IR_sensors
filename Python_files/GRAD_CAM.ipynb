# %%
import pickle
import cv2
import torch

import torchvision.transforms as transforms
from architectures import CNN_grad_cam_new_big
from grad_cam import GradCAM, apply_grad_cam, display_images, display_and_save_grad_cam
code_word = '4_covid_grad_cam_new_smaller'
path_to_models = "D:/IR_blobs/IR_blobs/models"
task = '4_class_covid'
# Load your trained model
model = CNN_grad_cam_new_big(class_number=4)  # Replace with the number of classes in your model
model.load_state_dict(torch.load(f"{path_to_models}/model_{code_word}"))  # Load model weights
model.eval()
# Out:
# CNN_grad_cam_new_big(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1))
#   (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(16, 8, kernel_size=(5, 5), stride=(1, 1))
#   (bn3): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(8, 3, kernel_size=(3, 3), stride=(1, 1))
#   (bn4): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=192, out_features=16, bias=True)
#   (fc2): Linear(in_features=16, out_features=4, bias=True)
# )

# %%
# Unpickle the Datasets
with open(f'D:/IR_blobs/IR_blobs/loaders/train_set_{task}', 'rb') as f:
   train_set = pickle.load(f)
#with open(f'D:/IR_blobs/IR_blobs/loaders/val_loader_{code_word}.pkl', 'rb') as f:
#    val_loader = pickle.load(f)
with open(f'D:/IR_blobs/IR_blobs/loaders/test_set_{task}.pkl', 'rb') as f:
    test_set = pickle.load(f)

# %%
len(test_set)
# Out:
# 25534

# %%
index_ = 12000
ratio = 0.5
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 0
# label: 0
# C:\Users\AndreiP\anaconda3\envs\IR_blobs\lib\site-packages\torch\nn\modules\module.py:1344: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %%
index_ = 19002
ratio = 0.5
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 1
# label: 1

# %%
index_ = 19700
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 1
# label: 1

# %%
#MAKE SENSE
index_ = 25105
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 3
# label: 3

# %%
index_ = 15000
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 1
# label: 1

# %%
#MAKE SENSE
index_ = 23500
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 2
# label: 2

# %%
#MAKE SENSE
index_ = 23800
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 2
# label: 2

# %%
#MAKE SENSE
index_ = 23900
ratio = 0.4
display_and_save_grad_cam(model, test_set, index_, ratio, save = False, path_to_folder = "D:/IR_blobs/IR_blobs/gradcam_images")
# Out:
# prediction: 2
# label: 2
